# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/schwaaweb/aimlds1_11-NLP/blob/master/M11_A_DJ_NLP_Assignment.ipynb)

# %% [markdown]
# ### Assignment: Natural Language Processing

# %% [markdown]
# In this assignment, you will work with a data set that contains restaurant reviews. You will use a Naive Bayes model to classify the reviews (positive or negative) based on the words in the review.  The main objective of this assignment is gauge the performance of a Naive Bayes model by using a confusion matrix; however in order to ascertain the efficiacy of the model, you will have to first train the Naive Bayes model with a portion (i.e. 70%) of the underlying data set and then test it against the remainder of the data set . Before you can train the model, you will have to go through a sequence of steps to get the data ready for training the model.
#
# Steps you may need to perform:
#
# **1) **Read in the list of restaurant reviews
#
# **2)** Convert the reviews into a list of tokens
#
# **3) **You will most likely have to eliminate stop words
#
# **4)** You may have to utilize stemming or lemmatization to determine the base form of the words
#
# **5) **You will have to vectorize the data (i.e. construct a document term/word matix) wherein select words from the reviews will constitute the columns of the matrix and the individual reviews will be part of the rows of the matrix
#
# **6) ** Create 'Train' and 'Test' data sets (i.e. 70% of the underlying data set will constitute the training set and 30% of the underlying data set will constitute the test set)
#
# **7)** Train a Naive Bayes model on the Train data set and test it against the test data set
#
# **8) **Construct a confusion matirx to gauge the performance of the model
#
# **Dataset**: https://www.dropbox.com/s/yl5r7kx9nq15gmi/Restaurant_Reviews.tsv?raw=1

# %% [markdown]
# **1) **Read in the list of restaurant reviews

# %%
#%%time
#!wget -c https://www.dropbox.com/s/yl5r7kx9nq15gmi/Restaurant_Reviews.tsv?raw=1 && mv Restaurant_Reviews.tsv?raw=1 Restaurant_Reviews.tsv
# !ls -lh *tsv
# Out:
# -rw-r--r--@ 1 darwinm  staff    60K Jun 13 17:43 Restaurant_Reviews.tsv

# %%
# %%time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import re
import string
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package qc to /Users/darwinm/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /Users/darwinm/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# CPU times: user 4.32 s, sys: 1.79 s, total: 6.1 s
# Wall time: 50.3 s

# %%
df = pd.read_csv('Restaurant_Reviews.tsv', sep='\t')
df.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
df.tail()
# Out:
#                                                 Review  Liked
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0

# %% [markdown]
# **2)** Convert the reviews into a list of tokens

# %%
review = df['Review'] # dropping the like here
print(review)
len(review)
# Out:
# 0                               Wow... Loved this place.
# 1                                     Crust is not good.
# 2              Not tasty and the texture was just nasty.
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu was great and so wer...
# 5         Now I am getting angry and I want my damn pho.
# 6                  Honeslty it didn't taste THAT fresh.)
# 7      The potatoes were like rubber and you could te...
# 8                              The fries were great too.
# 9                                         A great touch.
# 10                              Service was very prompt.
# 11                                    Would not go back.
# 12     The cashier had no care what so ever on what I...
# 13     I tried the Cape Cod ravoli, chicken, with cra...
# 14     I was disgusted because I was pretty sure that...
# 15     I was shocked because no signs indicate cash o...
# 16                                   Highly recommended.
# 17                Waitress was a little slow in service.
# 18     This place is not worth your time, let alone V...
# 19                                  did not like at all.
# 20                                   The Burrittos Blah!
# 21                                    The food, amazing.
# 22                                 Service is also cute.
# 23     I could care less... The interior is just beau...
# 24                                    So they performed.
# 25     That's right....the red velvet cake.....ohhh t...
# 26            - They never brought a salad we asked for.
# 27     This hole in the wall has great Mexican street...
# 28     Took an hour to get our food only 4 tables in ...
# 29                     The worst was the salmon sashimi.
#                              ...
# 970    I immediately said I wanted to talk to the man...
# 971                      The ambiance isn't much better.
# 972    Unfortunately, it only set us up for disapppoi...
# 973                                The food wasn't good.
# 974    Your servers suck, wait, correction, our serve...
# 975        What happened next was pretty....off putting.
# 976    too bad cause I know it's family owned, I real...
# 977                 Overpriced for what you are getting.
# 978                 I vomited in the bathroom mid lunch.
# 979    I kept looking at the time and it had soon bec...
# 980    I have been to very few places to eat that und...
# 981    We started with the tuna sashimi which was bro...
# 982                              Food was below average.
# 983    It sure does beat the nachos at the movies but...
# 984         All in all, Ha Long Bay was a bit of a flop.
# 985    The problem I have is that they charge $11.99 ...
# 986    Shrimp- When I unwrapped it (I live only 1/2 a...
# 987       It lacked flavor, seemed undercooked, and dry.
# 988    It really is impressive that the place hasn't ...
# 989    I would avoid this place if you are staying in...
# 990    The refried beans that came with my meal were ...
# 991           Spend your money and time some place else.
# 992    A lady at the table next to us found a live gr...
# 993              the presentation of the food was awful.
# 994             I can't tell you how disappointed I was.
# 995    I think food should have flavor and texture an...
# 996                             Appetite instantly gone.
# 997    Overall I was not impressed and would not go b...
# 998    The whole experience was underwhelming, and I ...
# 999    Then, as if I hadn't wasted enough of my life ...
# Name: Review, Length: 1000, dtype: object
# 1000

# %% [markdown]
# **3) **You will most likely have to eliminate stop words

# %% [markdown]
# **4)** You may have to utilize stemming or lemmatization to determine the base form of the words

# %%
stopwords = nltk.corpus.stopwords.words('english')
ps = nltk.PorterStemmer()


#Elmiminate punctations
#Tokenize based on whitespace
#Stem the text
#Remove stopwords
def process_text(txt):
    eliminate_punct = "".join([word.lower() for word in txt if word not in string.punctuation])
    tokens = re.split('\W+', txt)
    txt = [ps.stem(word) for word in tokens if word not in stopwords]
    return txt
  
df['clean_review'] = df['Review'].apply(lambda x: process_text(x))

df.head()
# Out:
#                                               Review  Liked  \
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1
#
#                                         clean_review
# 0                               [wow, love, place, ]
# 1                                    [crust, good, ]
# 2                      [not, tasti, textur, nasti, ]
# 3  [stop, late, may, bank, holiday, rick, steve, ...
# 4                [the, select, menu, great, price, ]

# %%
import gensim

# Use the Gensim document to create a dictionary - a dictionary maps every word to a number
dictionary = gensim.corpora.Dictionary(df['clean_review'])
# Examine the length of the dictionary
num_of_words = len(dictionary)
print("# of words in dictionary: {}".format(num_of_words))
#for index,word in dictionary.items():
#    print(index,word)
print(dictionary)
# Out:
# # of words in dictionary: 1668
# Dictionary(1668 unique tokens: ['', 'love', 'place', 'wow', 'crust']...)

# %%
#print(dictionary.token2id)

# %% [markdown]
# **5) **You will have to vectorize the data (i.e. construct a document term/word matix) wherein select words from the reviews will constitute the columns of the matrix and the individual reviews will be part of the rows of the matrix

# %%
from pprint import pprint

# %%
corpus = [dictionary.doc2bow(list_corpus)]

# %%
# %%time


from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

def cv(data):
    count_vectorizer = CountVectorizer()

    emb = count_vectorizer.fit_transform(data)

    return emb, count_vectorizer

list_corpus = df["clean_review"].tolist()
list_labels = df["Liked"].tolist()

X_train, X_test, y_train, y_test = train_test_split(list_corpus, list_labels, test_size=0.3, random_state=42)

#X_train_counts, count_vectorizer = cv(X_train)
#X_test_counts = count_vectorizer.transform(X_test)
#pprint(X_train)

#from sklearn.feature_extraction.text import CountVectorizer

#count_vect = CountVectorizer(analyzer=process_text, max_features=1668)
#W_counts = count_vect.fit_transform(df['clean_review'])
#print(W_counts.shape)
#print(count_vect.get_feature_names())
# Out:
# [['We',
#   'wait',
#   'thirti',
#   'minut',
#   'seat',
#   'although',
#   '8',
#   'vacant',
#   'tabl',
#   'folk',
#   'wait',
#   ''],
#  ['I', 'take', 'busi', 'dinner', 'dollar', 'elsewher', ''],
#  ['seafood',
#   'limit',
#   'boil',
#   'shrimp',
#   'crab',
#   'leg',
#   'crab',
#   'leg',
#   'definit',
#   'tast',
#   'fresh',
#   ''],
#  ['furthermor', 'even', 'find', 'hour', 'oper', 'websit', ''],
#  ['My', 'girlfriend', 'veal', 'bad', ''],
#  ['mayb',
#   'vegetarian',
#   'fare',
#   'I',
#   'twice',
#   'I',
#   'thought',
#   'averag',
#   'best',
#   ''],
#  ['I', 'love', 'place', ''],
#  ['I', 'swung', 'give', 'tri', 'deepli', 'disappoint', ''],
#  ['the', 'place', 'fairli', 'clean', 'food', 'simpli', 'worth', ''],
#  ['food', 'delici', ''],
#  ['It', 'pale', 'color', 'instead', 'nice', 'char', 'NO', 'flavor', ''],
#  ['everyth', 'good', 'tasti', ''],
#  ['over', 'rate', ''],
#  ['would', 'recommend', 'other', ''],
#  ['the',
#   'food',
#   'delici',
#   'spici',
#   'enough',
#   'sure',
#   'ask',
#   'spicier',
#   'prefer',
#   'way',
#   ''],
#  ['I', 'insult', ''],
#  ['As', 'main', 'also', 'uninspir', ''],
#  ['everyon', 'treat', 'equal', 'special', ''],
#  ['the', 'han', 'nan', 'chicken', 'also', 'tasti', ''],
#  ['My', 'friend', 'love', 'salmon', 'tartar', ''],
#  ['there',
#   'much',
#   'good',
#   'food',
#   'vega',
#   'I',
#   'feel',
#   'cheat',
#   'wast',
#   'eat',
#   'opportun',
#   'go',
#   'rice',
#   'compani',
#   ''],
#  ['I', 'give', '2', 'thumb'],
#  ['the',
#   'potato',
#   'chip',
#   'order',
#   'sad',
#   'I',
#   'could',
#   'probabl',
#   'count',
#   'mani',
#   'chip',
#   'box',
#   'probabl',
#   'around',
#   '12',
#   ''],
#  ['I',
#   'ask',
#   'multipl',
#   'time',
#   'wine',
#   'list',
#   'time',
#   'ignor',
#   'I',
#   'went',
#   'hostess',
#   'got',
#   'one',
#   ''],
#  ['So',
#   'nutshel',
#   '1',
#   'the',
#   'restaraunt',
#   'smell',
#   'like',
#   'combin',
#   'dirti',
#   'fish',
#   'market',
#   'sewer',
#   ''],
#  ['overal', 'I', 'impress', 'noca', ''],
#  ['the', 'veget', 'fresh', 'sauc', 'feel', 'like', 'authent', 'thai', ''],
#  ['thi', 'small', 'famili', 'restaur', 'fine', 'dine', 'establish', ''],
#  ['not', 'thing', ''],
#  ['the', 'manag', 'rude', ''],
#  ['our', 'server', 'nice', 'attent', 'serv', 'staff', ''],
#  ['she', 'order', 'toast', 'english', 'muffin', 'came', 'untoast', ''],
#  ['the', 'food', 'great', 'alway', 'compliment', 'chef', ''],
#  ['the',
#   'staff',
#   'alway',
#   'super',
#   'friendli',
#   'help',
#   'especi',
#   'cool',
#   'bring',
#   'two',
#   'small',
#   'boy',
#   'babi',
#   ''],
#  ['wow', 'love', 'place', ''],
#  ['By',
#   'point',
#   'friend',
#   'I',
#   'basic',
#   'figur',
#   'place',
#   'joke',
#   'mind',
#   'make',
#   'publicli',
#   'loudli',
#   'known',
#   ''],
#  ['the', 'atmospher', 'fun', ''],
#  ['even', 'hello', 'right', ''],
#  ['all',
#   'excel',
#   'restaur',
#   'highlight',
#   'great',
#   'servic',
#   'uniqu',
#   'menu',
#   'beauti',
#   'set',
#   ''],
#  ['the', 'best', 'place', 'vega', 'breakfast', 'check', 'sat', 'sun', ''],
#  ['the', 'steak', 'well', 'trim', 'also', 'perfectli', 'cook', ''],
#  ['today',
#   'first',
#   'tast',
#   'buldogi',
#   'gourmet',
#   'hot',
#   'dog',
#   'I',
#   'tell',
#   'I',
#   'ever',
#   'thought',
#   'possibl',
#   ''],
#  ['the', 'waitress', 'friendli', ''],
#  ['host', 'staff', 'lack', 'better', 'word', 'bitch', ''],
#  ['servic',
#   'excel',
#   'price',
#   'pretti',
#   'reason',
#   'consid',
#   'vega',
#   'locat',
#   'insid',
#   'crystal',
#   'shop',
#   'mall',
#   'aria',
#   ''],
#  ['from',
#   'dinner',
#   'companion',
#   'told',
#   'everyth',
#   'fresh',
#   'nice',
#   'textur',
#   'tast',
#   ''],
#  ['I', 'would', 'recommend', 'save', 'room', ''],
#  ['and', 'drink', 'weak', 'peopl', ''],
#  ['In', 'summari', 'larg', 'disappoint', 'dine', 'experi', ''],
#  ['the',
#   'build',
#   'seem',
#   'pretti',
#   'neat',
#   'bathroom',
#   'pretti',
#   'trippi',
#   'I',
#   'eat',
#   ''],
#  ['I',
#   'also',
#   'decid',
#   'send',
#   'back',
#   'waitress',
#   'look',
#   'like',
#   'verg',
#   'heart',
#   'attack',
#   ''],
#  ['the', 'chef', 'friendli', 'good', 'job', ''],
#  ['I', 'want', 'first', 'say', 'server', 'great', 'perfect', 'servic', ''],
#  ['A', 'great', 'way', 'finish', 'great', ''],
#  ['just', 'know', 'slow', ''],
#  ['penn', 'vodka', 'excel', ''],
#  ['good', 'beer', 'drink', 'select', 'good', 'food', 'select', ''],
#  ['what', 'mistak', ''],
#  ['you', 'disappoint', ''],
#  ['nice',
#   'blanket',
#   'moz',
#   'top',
#   'feel',
#   'like',
#   'done',
#   'cover',
#   'subpar',
#   'food',
#   ''],
#  ['We', 'tri', 'like', 'place', '10', 'time', 'I', 'think', 'done', ''],
#  ['boy', 'sucker', 'dri', ''],
#  ['great',
#   'subway',
#   'fact',
#   'good',
#   'come',
#   'everi',
#   'subway',
#   'meet',
#   'expect',
#   ''],
#  ['I', 'think', 'go', 'back', 'anytim', 'soon', ''],
#  ['restaur', 'alway', 'full', 'never', 'wait', ''],
#  ['took',
#   'hour',
#   'get',
#   'food',
#   '4',
#   'tabl',
#   'restaur',
#   'food',
#   'luke',
#   'warm',
#   'our',
#   'sever',
#   'run',
#   'around',
#   'like',
#   'total',
#   'overwhelm',
#   ''],
#  ['what', 'bother', 'slow', 'servic', ''],
#  ['I',
#   'salad',
#   'wing',
#   'ice',
#   'cream',
#   'dessert',
#   'left',
#   'feel',
#   'quit',
#   'satisfi',
#   ''],
#  ['thi', 'disgrac', ''],
#  ['So', 'flavor', 'perfect', 'amount', 'heat', ''],
#  ['bacon', 'hella', 'salti', ''],
#  ['I',
#   'work',
#   'hospit',
#   'industri',
#   'paradis',
#   'valley',
#   'refrain',
#   'recommend',
#   'cibo',
#   'longer',
#   ''],
#  ['don', ''],
#  ['lordi', 'khao', 'soi', 'dish', 'miss', 'curri', 'lover', ''],
#  ['honeslti', 'tast', 'that', 'fresh', ''],
#  ['there',
#   'warm',
#   'feel',
#   'servic',
#   'I',
#   'felt',
#   'like',
#   'guest',
#   'special',
#   'treat',
#   ''],
#  ['We', 'group', '70', 'claim', 'would', '40', 'handl', 'us', 'beauti', ''],
#  ['It', 'took', '30', 'min', 'get', 'milkshak', 'noth', 'chocol', 'milk', ''],
#  ['I',
#   'serious',
#   'cannot',
#   'believ',
#   'owner',
#   'mani',
#   'unexperienc',
#   'employe',
#   'run',
#   'around',
#   'like',
#   'chicken',
#   'head',
#   'cut',
#   ''],
#  ['It', 'pack', ''],
#  ['If', 'roll', 'eye', 'may', 'stay', 'not', 'sure', 'go', 'back', 'tri', ''],
#  ['the', 'bathroom', 'clean', 'place', 'well', 'decor', ''],
#  ['pay',
#   '7',
#   '85',
#   'hot',
#   'dog',
#   'fri',
#   'look',
#   'like',
#   'came',
#   'kid',
#   'meal',
#   'wienerschnitzel',
#   'idea',
#   'good',
#   'meal',
#   ''],
#  ['great',
#   'place',
#   'coupl',
#   'drink',
#   'watch',
#   'sport',
#   'event',
#   'wall',
#   'cover',
#   'TV',
#   ''],
#  ['the',
#   'shower',
#   'area',
#   'outsid',
#   'rins',
#   'take',
#   'full',
#   'shower',
#   'unless',
#   'mind',
#   'nude',
#   'everyon',
#   'see',
#   ''],
#  ['the', 'RI', 'style', 'calamari', 'joke', ''],
#  ['I',
#   'also',
#   'tast',
#   'mom',
#   'multi',
#   'grain',
#   'pumpkin',
#   'pancak',
#   'pecan',
#   'butter',
#   'amaz',
#   'fluffi',
#   'delici',
#   ''],
#  ['they',
#   'good',
#   'select',
#   'food',
#   'includ',
#   'massiv',
#   'meatloaf',
#   'sandwich',
#   'crispi',
#   'chicken',
#   'wrap',
#   'delish',
#   'tuna',
#   'melt',
#   'tasti',
#   'burger',
#   ''],
#  ['the', 'refri', 'bean', 'came', 'meal', 'dri', 'crusti', 'food', 'bland', ''],
#  ['the', 'flair', 'bartend', 'absolut', 'amaz', ''],
#  ['I', 'order', 'lemon', 'raspberri', 'ice', 'cocktail', 'also', 'incred', ''],
#  ['there', 'deal', 'good', 'enough', 'would', 'drag', 'establish', ''],
#  ['We',
#   'much',
#   'say',
#   'place',
#   'walk',
#   'expect',
#   'amaz',
#   'quickli',
#   'disappoint',
#   ''],
#  ['will', 'go', 'back', 'next', 'trip', ''],
#  ['My',
#   'breakfast',
#   'perpar',
#   'great',
#   'beauti',
#   'present',
#   '3',
#   'giant',
#   'slice',
#   'toast',
#   'lightli',
#   'dust',
#   'powder',
#   'sugar',
#   ''],
#  ['the',
#   'heart',
#   'attack',
#   'grill',
#   'downtown',
#   'vega',
#   'absolut',
#   'flat',
#   'line',
#   'excus',
#   'restaur',
#   ''],
#  ['left', 'frustrat', ''],
#  ['anyway', 'FS', 'restaur', 'wonder', 'breakfast', 'lunch', ''],
#  ['thi', 'great', 'place', 'eat', ''],
#  ['overal', 'I', 'impress', 'would', 'go', 'back', ''],
#  ['So', 'perform', ''],
#  ['thi',
#   'due',
#   'fact',
#   'took',
#   '20',
#   'minut',
#   'acknowledg',
#   'anoth',
#   '35',
#   'minut',
#   'get',
#   'food',
#   'kept',
#   'forget',
#   'thing',
#   ''],
#  ['the', 'steak', 'shrimp', 'opinion', 'best', 'entre', 'GC', ''],
#  ['thi', 'place', 'two', 'thumb', 'way', ''],
#  ['they', 'realli', 'want', 'make', 'experi', 'good', 'one', ''],
#  ['hawaiian',
#   'breez',
#   'mango',
#   'magic',
#   'pineappl',
#   'delight',
#   'smoothi',
#   'I',
#   'tri',
#   'far',
#   'good',
#   ''],
#  ['It', 'bad', 'I', 'lost', 'heart', 'finish', ''],
#  ['omg', 'food', 'delicioso', ''],
#  ['He',
#   'came',
#   'run',
#   'us',
#   'realiz',
#   'husband',
#   'left',
#   'sunglass',
#   'tabl',
#   ''],
#  ['My', 'gyro', 'basic', 'lettuc', ''],
#  ['drive', 'get', ''],
#  ['needless', 'say', 'I', 'go', 'back', 'anytim', 'soon', ''],
#  ['join', 'club', 'get', 'awesom', 'offer', 'via', 'email', ''],
#  ['the', 'seafood', 'fresh', 'gener', 'portion', ''],
#  ['the', 'season', 'fruit', 'fresh', 'white', 'peach', 'pure', ''],
#  ['that', 'said', 'mouth', 'belli', 'still', 'quit', 'pleas', ''],
#  ['dessert', 'panna', 'cotta', 'amaz', ''],
#  ['No', 'one', 'tabl', 'thought', 'food', 'averag', 'worth', 'wait', ''],
#  ['anyway', 'I', 'think', 'go', 'back', ''],
#  ['sauc', 'tasteless', ''],
#  ['thi', 'place', 'worth', 'time', 'let', 'alon', 'vega', ''],
#  ['onli',
#   'pro',
#   'larg',
#   'seat',
#   'area',
#   'nice',
#   'bar',
#   'area',
#   'great',
#   'simpl',
#   'drink',
#   'menu',
#   'the',
#   'best',
#   'brick',
#   'oven',
#   'pizza',
#   'homemad',
#   'dough',
#   ''],
#  ['the', 'select', 'food', 'best', ''],
#  ['AN', 'hour', 'serious', ''],
#  ['order', 'appet', 'took', '40', 'minut', 'pizza', 'anoth', '10', 'minut', ''],
#  ['would', 'come', 'back', 'I', 'sushi', 'crave', 'vega', ''],
#  ['thi', 'place', ''],
#  ['thi', 'place', 'receiv', 'star', 'appet', ''],
#  ['after', 'wait', 'hour', 'seat', 'I', 'greatest', 'mood', ''],
#  ['you', 'beat', ''],
#  ['great', 'pizza', 'salad', ''],
#  ['the', 'buffet', 'small', 'food', 'offer', 'bland', ''],
#  ['It', 'delici', ''],
#  ['the',
#   'food',
#   'good',
#   'I',
#   'enjoy',
#   'everi',
#   'mouth',
#   'enjoy',
#   'relax',
#   'venu',
#   'coupl',
#   'small',
#   'famili',
#   'group',
#   'etc',
#   ''],
#  ['I', 'think'],
#  ['the',
#   'cashier',
#   'care',
#   'ever',
#   'I',
#   'say',
#   'still',
#   'end',
#   'wayyy',
#   'overpr',
#   ''],
#  ['I', 'dress', 'treat', 'rude', ''],
#  ['the', 'staff', 'great', 'ambianc', 'great', ''],
#  ['the', 'servic', 'terribl', 'food', 'mediocr', ''],
#  ['the', 'cow', 'tongu', 'cheek', 'taco', 'amaz', ''],
#  ['hope', 'bode', 'go', 'busi', 'someon', 'cook', 'come', ''],
#  ['wait', 'wait', 'wait', ''],
#  ['I',
#   'immedi',
#   'said',
#   'I',
#   'want',
#   'talk',
#   'manag',
#   'I',
#   'want',
#   'talk',
#   'guy',
#   'shot',
#   'firebal',
#   'behind',
#   'bar',
#   ''],
#  ['not', 'much', 'flavor', 'poorli', 'construct', ''],
#  ['just', 'spici', 'enough', 'perfect', 'actual', ''],
#  ['If', 'look', 'authent', 'thai', 'food', 'go', 'els', ''],
#  ['high', 'qualiti', 'chicken', 'chicken', 'caesar', 'salad', ''],
#  ['the', 'servic', 'leav', 'lot', 'desir', ''],
#  ['the',
#   'sweet',
#   'potato',
#   'tot',
#   'good',
#   'onion',
#   'ring',
#   'perfect',
#   'close',
#   'I',
#   ''],
#  ['what', 'great', 'doubl', 'cheeseburg', ''],
#  ['great', 'food', 'great', 'servic', 'clean', 'friendli', 'set', ''],
#  ['My', 'boyfriend', 'sat', 'bar', 'complet', 'delight', 'experi', ''],
#  ['We',
#   'walk',
#   'away',
#   'stuf',
#   'happi',
#   'first',
#   'vega',
#   'buffet',
#   'experi',
#   ''],
#  ['avoid', 'cost', ''],
#  ['the', 'light', 'dark', 'enough', 'set', 'mood', ''],
#  ['order', 'burger', 'rare', 'came', 'done', ''],
#  ['I', 'two', 'bite', 'refus', 'eat', 'anymor', ''],
#  ['googl', 'mediocr', 'I', 'imagin', 'smashburg', 'pop', ''],
#  ['best', 'taco', 'town', 'far', ''],
#  ['for', 'servic', 'I', 'give', 'star', ''],
#  ['I',
#   'guess',
#   'I',
#   'known',
#   'place',
#   'would',
#   'suck',
#   'insid',
#   'excalibur',
#   'I',
#   'use',
#   'common',
#   'sens',
#   ''],
#  ['nice', 'spici', 'tender', ''],
#  ['I',
#   'realli',
#   'enjoy',
#   'crema',
#   'café',
#   'expand',
#   'I',
#   'even',
#   'told',
#   'friend',
#   'best',
#   'breakfast',
#   ''],
#  ['If',
#   'someon',
#   'order',
#   'two',
#   'taco',
#   'think',
#   'may',
#   'part',
#   'custom',
#   'servic',
#   'ask',
#   'combo',
#   'ala',
#   'cart',
#   ''],
#  ['If', 'want', 'healthi', 'authent', 'ethic', 'food', 'tri', 'place', ''],
#  ['thi', 'one', 'better', 'buffet', 'I', ''],
#  ['good', 'price', ''],
#  ['I', 'realli', 'enjoy', 'eat', ''],
#  ['similarli',
#   'deliveri',
#   'man',
#   'say',
#   'word',
#   'apolog',
#   'food',
#   '45',
#   'minut',
#   'late',
#   ''],
#  ['nargil', 'I', 'think', 'great', ''],
#  ['total', 'wast', 'OF', 'time', ''],
#  ['never',
#   'hard',
#   'rock',
#   'casino',
#   'will',
#   'never',
#   'ever',
#   'step',
#   'forward',
#   'IN',
#   'IT',
#   'again',
#   ''],
#  ['the', 'food', 'par', 'denni', 'say', 'good', ''],
#  ['everyth', 'fresh', 'delici', ''],
#  ['first',
#   'bathroom',
#   'locat',
#   'dirti',
#   'seat',
#   'cover',
#   'replenish',
#   'plain',
#   'yucki',
#   ''],
#  ['It', 'realli', 'impress', 'place', 'close', ''],
#  ['thi', 'place', 'disgust', ''],
#  ['We', 'go', 'back', ''],
#  ['the', 'food', 'good', ''],
#  ['It', 'extrem', 'crumbi', 'pretti', 'tasteless', ''],
#  ['I', 'check', 'place', 'coupl', 'year', 'ago', 'impress', ''],
#  ['say', 'bye', 'bye', 'tip', 'ladi', ''],
#  ['would', 'go', 'back', ''],
#  ['I', 'probabl', 'one', 'peopl', 'ever', 'go', 'ian', 'like', ''],
#  ['If',
#   'love',
#   'authent',
#   'mexican',
#   'food',
#   'want',
#   'whole',
#   'bunch',
#   'interest',
#   'yet',
#   'delici',
#   'meat',
#   'choos',
#   'need',
#   'tri',
#   'place',
#   ''],
#  ['On', 'posit', 'note', 'server', 'attent', 'provid', 'great', 'servic', ''],
#  ['hard',
#   'judg',
#   'whether',
#   'side',
#   'good',
#   'gross',
#   'melt',
#   'styrofoam',
#   'want',
#   'eat',
#   'fear',
#   'get',
#   'sick',
#   ''],
#  ['when',
#   'mom',
#   'I',
#   'got',
#   'home',
#   'immedi',
#   'got',
#   'sick',
#   'bite',
#   'salad',
#   ''],
#  ['So', 'go', 'look', 'good', 'food', ''],
#  ['thi', 'first', 'crawfish', 'experi', 'delici', ''],
#  ['I', 'better', 'bagel', 'groceri', 'store', ''],
#  ['It', 'regular', 'stop', 'trip', 'phoenix', ''],
#  ['I',
#   'wait',
#   '30',
#   'minut',
#   'get',
#   'drink',
#   'longer',
#   'get',
#   '2',
#   'arepa',
#   ''],
#  ['our',
#   'server',
#   'fantast',
#   'found',
#   'wife',
#   'love',
#   'roast',
#   'garlic',
#   'bone',
#   'marrow',
#   'ad',
#   'extra',
#   'meal',
#   'anoth',
#   'marrow',
#   'go',
#   ''],
#  ['thi', 'serious', 'good', 'pizza', 'I', 'expert', 'connisseur', 'topic', ''],
#  ['not', 'weekli', 'haunt', 'definit', 'place', 'come', 'back', 'everi', ''],
#  ['each', 'day', 'week', 'differ', 'deal', 'delici', ''],
#  ['but', 'I', 'complet', 'gross', ''],
#  ['I', 'start', 'review', 'two', 'star', 'I', 'edit', 'give', 'one', ''],
#  ['We', 'defin', 'enjoy', ''],
#  ['I', 'gave', '5', 'star', 'I', 'give', '5', 'star', ''],
#  ['the', 'atmospher', 'modern', 'hip', 'maintain', 'touch', 'cozi', ''],
#  ['To',
#   'summar',
#   'food',
#   'incred',
#   'nay',
#   'transcend',
#   'noth',
#   'bring',
#   'joy',
#   'quit',
#   'like',
#   'memori',
#   'pneumat',
#   'condiment',
#   'dispens',
#   ''],
#  ['veri', 'sad', ''],
#  ['the', 'classic', 'main', 'lobster', 'roll', 'fantast', ''],
#  ['insult',
#   'profound',
#   'deuchebaggeri',
#   'go',
#   'outsid',
#   'smoke',
#   'break',
#   'serv',
#   'solidifi',
#   ''],
#  ['damn', 'good', 'steak', ''],
#  ['the', 'food', 'terribl', ''],
#  ['then', 'food', 'came', 'disappoint', 'ensu', ''],
#  ['the', 'wonton', 'thin', 'thick', 'chewi', 'almost', 'melt', 'mouth', ''],
#  ['I', 'well', 'would', 'given', 'godfath', 'zero', 'star', 'possibl', ''],
#  ['worst', 'martini', 'ever', ''],
#  ['great', 'servic', 'food', ''],
#  ['I', 'shock', 'sign', 'indic', 'cash', ''],
#  ['favorit', 'place', 'town', 'shawarrrrrrma', ''],
#  ['the', 'jalapeno', 'bacon', 'soooo', 'good', ''],
#  ['lobster',
#   'bisqu',
#   'bussel',
#   'sprout',
#   'risotto',
#   'filet',
#   'all',
#   'need',
#   'salt',
#   'pepper',
#   'cours',
#   'none',
#   'tabl',
#   ''],
#  ['We', 'liter', 'sat', '20', 'minut', 'one', 'ask', 'take', 'order', ''],
#  ['It',
#   'sure',
#   'beat',
#   'nacho',
#   'movi',
#   'I',
#   'would',
#   'expect',
#   'littl',
#   'bit',
#   'come',
#   'restaur',
#   ''],
#  ['servic', 'also', 'cute', ''],
#  ['sadli',
#   'gordon',
#   'ramsey',
#   'steak',
#   'place',
#   'shall',
#   'sharpli',
#   'avoid',
#   'next',
#   'trip',
#   'vega',
#   ''],
#  ['the', 'staff', 'attent', ''],
#  ['talk', 'great', 'custom', 'servic', 'cours', 'back', ''],
#  ['spaghetti', 'noth', 'special', 'whatsoev', ''],
#  ['We', 'love', 'biscuit', ''],
#  ['nice', 'ambianc', ''],
#  ['best',
#   'servic',
#   'food',
#   'ever',
#   'maria',
#   'server',
#   'good',
#   'friendli',
#   'made',
#   'day',
#   ''],
#  ['great', 'brunch', 'spot', ''],
#  ['four',
#   'star',
#   'food',
#   'guy',
#   'blue',
#   'shirt',
#   'great',
#   'vibe',
#   'still',
#   'let',
#   'us',
#   'eat',
#   ''],
#  ['best', 'breakfast', 'buffet', ''],
#  ['all', 'tapa', 'dish', 'delici', ''],
#  ['We',
#   'got',
#   'food',
#   'appar',
#   'never',
#   'heard',
#   'salt',
#   'batter',
#   'fish',
#   'chewi',
#   ''],
#  ['the', 'grill', 'chicken', 'tender', 'yellow', 'saffron', 'season', ''],
#  ['I', 'would', 'definit', 'recommend', 'wing', 'well', 'pizza', ''],
#  ['We', 'could', 'believ', 'dirti', 'oyster', ''],
#  ['So', 'absolutley', 'fantast', ''],
#  ['crostini', 'came', 'salad', 'stale', ''],
#  ['the', 'scallop', 'dish', 'quit', 'appal', 'valu', 'well', ''],
#  ['the',
#   'food',
#   'bare',
#   'lukewarm',
#   'must',
#   'sit',
#   'wait',
#   'server',
#   'bring',
#   'us',
#   ''],
#  ['will', 'back', ''],
#  ['what', 'I', 'realli', 'like', 'crepe', 'station', ''],
#  ['you', 'cant', 'go', 'wrong', 'food', ''],
#  ['the',
#   'descript',
#   'said',
#   'yum',
#   'yum',
#   'sauc',
#   'anoth',
#   'said',
#   'eel',
#   'sauc',
#   'yet',
#   'anoth',
#   'said',
#   'spici',
#   'mayo',
#   'well',
#   'none',
#   'roll',
#   'sauc',
#   ''],
#  ['I', 'dont', 'think', 'I', 'back', 'long', 'time', ''],
#  ['I', 'better', 'atmospher', ''],
#  ['not', 'good', 'stretch', 'imagin', ''],
#  ['By', 'far', 'best', 'cheesecurd', 'ever', ''],
#  ['won', 'ever', 'go', ''],
#  ['the',
#   'waitress',
#   'friendli',
#   'happi',
#   'accomod',
#   'vegan',
#   'veggi',
#   'option',
#   ''],
#  ['bland',
#   'not',
#   'like',
#   'place',
#   'number',
#   'reason',
#   'I',
#   'want',
#   'wast',
#   'time',
#   'bad',
#   'review',
#   'I',
#   'leav',
#   ''],
#  ['It', 'pretti', 'gross', ''],
#  ['don', 'wast', 'time', ''],
#  ['the',
#   'sergeant',
#   'pepper',
#   'beef',
#   'sandwich',
#   'auju',
#   'sauc',
#   'excel',
#   'sandwich',
#   'well',
#   ''],
#  ['not', 'much', 'seafood', 'like', '5', 'string', 'pasta', 'bottom', ''],
#  ['I', 'love', 'fri', 'bean', ''],
#  ['felt',
#   'insult',
#   'disrespect',
#   'could',
#   'talk',
#   'judg',
#   'anoth',
#   'human',
#   'like',
#   ''],
#  ['He', 'deserv', '5', 'star', ''],
#  ['just', 'good', 'I', 'year', 'ago', ''],
#  ['It', 'bad', 'food', 'damn', 'gener', ''],
#  ['I', 'eaten', 'multipl', 'time', 'time', 'food', 'delici', ''],
#  ['the', 'best', 'place', 'go', 'tasti', 'bowl', 'pho', ''],
#  ['then',
#   'I',
#   'wast',
#   'enough',
#   'life',
#   'pour',
#   'salt',
#   'wound',
#   'draw',
#   'time',
#   'took',
#   'bring',
#   'check',
#   ''],
#  ['they', 'excel', ''],
#  ['friend', 'pasta', 'also', 'bad', 'bare', 'touch', ''],
#  ['good', 'servic', 'clean', 'inexpens', 'boot', ''],
#  ['noth', 'special', ''],
#  ['A', 'fantast', 'neighborhood', 'gem', ''],
#  ['good', 'servic', 'check', ''],
#  ['Of', 'dish', 'salmon', 'best', 'great', ''],
#  ['but', 'I', 'like', ''],
#  ['We', 'watch', 'waiter', 'pay', 'lot', 'attent', 'tabl', 'ignor', 'us', ''],
#  ['We',
#   'thought',
#   'ventur',
#   'away',
#   'get',
#   'good',
#   'sushi',
#   'place',
#   'realli',
#   'hit',
#   'spot',
#   'night',
#   ''],
#  ['We', 'come', 'back', ''],
#  ['We',
#   'order',
#   'duck',
#   'rare',
#   'pink',
#   'tender',
#   'insid',
#   'nice',
#   'char',
#   'outsid',
#   ''],
#  ['It', 'take', '30', 'min', 'pancak', 'egg', ''],
#  ['It', 'also', 'took', 'forev', 'bring', 'us', 'check', 'ask', ''],
#  ['My', 'husband', 'I', 'ate', 'lunch', 'disappoint', 'food', 'servic', ''],
#  ['veri', 'good', 'though', ''],
#  ['cook', 'perfect', 'servic', 'impecc', ''],
#  ['ambienc', 'perfect', ''],
#  ['the', 'downsid', 'servic', ''],
#  ['like', ''],
#  ['the',
#   'first',
#   'time',
#   'I',
#   'ever',
#   'came',
#   'I',
#   'amaz',
#   'experi',
#   'I',
#   'still',
#   'tell',
#   'peopl',
#   'awesom',
#   'duck',
#   ''],
#  ['when', 'I', 'receiv', 'pita', 'huge', 'lot', 'meat', 'thumb', ''],
#  ['lastli', 'mozzarella', 'stick', 'best', 'thing', 'order', ''],
#  ['food', 'realli', 'good', 'I', 'got', 'full', 'petti', 'fast', ''],
#  ['great', 'steak', 'great', 'side', 'great', 'wine', 'amaz', 'dessert', ''],
#  ['I', 'chicken', 'pho', 'tast', 'bland', ''],
#  ['My', 'first', 'visit', 'hiro', 'delight', ''],
#  ['perhap',
#   'I',
#   'caught',
#   'night',
#   'judg',
#   'review',
#   'I',
#   'inspir',
#   'go',
#   'back',
#   ''],
#  ['', 'drink', 'took', 'close', '30', 'minut', 'come', 'one', 'point', ''],
#  ['the', 'servic', 'fair', 'best', ''],
#  ['and',
#   'chef',
#   'gener',
#   'time',
#   'even',
#   'came',
#   'around',
#   'twice',
#   'take',
#   'pictur',
#   ''],
#  ['main',
#   'thing',
#   'I',
#   'enjoy',
#   'crowd',
#   'older',
#   'crowd',
#   'around',
#   'mid',
#   '30',
#   ''],
#  ['I', 'probabl', 'come', 'back', ''],
#  ['some', 'highlight', 'great', 'qualiti', 'nigiri', ''],
#  ['We',
#   'wait',
#   'hour',
#   'breakfast',
#   'I',
#   'could',
#   'done',
#   '100',
#   'time',
#   'better',
#   'home',
#   ''],
#  ['they', 'also', 'best', 'chees', 'crisp', 'town', ''],
#  ['I', 'consid', 'theft', ''],
#  ['when', 'I', 'open', 'sandwich', 'I', 'impress', 'good', 'way', ''],
#  ['waitress', 'littl', 'slow', 'servic', ''],
#  ['phenomen', 'food', 'servic', 'ambianc', ''],
#  ['servic', 'except', 'food', 'good', 'review', ''],
#  ['We', '7', 'tabl', 'servic', 'pretti', 'fast', ''],
#  ['that',
#   'scream',
#   'legit',
#   'book',
#   'somethat',
#   'also',
#   'pretti',
#   'rare',
#   'vega',
#   ''],
#  ['del', 'taco', 'pretti', 'nasti', 'avoid', 'possibl', ''],
#  ['watch', 'prepar', 'delici', 'food', ''],
#  ['check', ''],
#  ['My', 'friend', 'like', 'bloodi', 'mari', ''],
#  ['It', 'awesom', ''],
#  ['the',
#   'burger',
#   'absolut',
#   'flavor',
#   'meat',
#   'total',
#   'bland',
#   'burger',
#   'overcook',
#   'charcoal',
#   'flavor',
#   ''],
#  ['pleas', 'stay', 'away', 'shrimp', 'stir', 'fri', 'noodl', ''],
#  ['the', 'servic', 'poor', 'that', 'nice', ''],
#  ['2', 'thumb', 'Up', ''],
#  ['special',
#   'thank',
#   'dylan',
#   'T',
#   'recommend',
#   'order',
#   'all',
#   'yummi',
#   'tummi',
#   ''],
#  ['total', 'brunch', 'fail', ''],
#  ['I',
#   'kept',
#   'look',
#   'time',
#   'soon',
#   'becom',
#   '35',
#   'minut',
#   'yet',
#   'still',
#   'food',
#   ''],
#  ['At',
#   'first',
#   'glanc',
#   'love',
#   'bakeri',
#   'cafe',
#   'nice',
#   'ambianc',
#   'clean',
#   'friendli',
#   'staff',
#   ''],
#  ['all', 'Ha', 'long', 'bay', 'bit', 'flop', ''],
#  ['the', 'thing', 'I', 'like', 'prime', 'rib', 'dessert', 'section', ''],
#  ['thi', 'new', 'fav', 'vega', 'buffet', 'spot', ''],
#  ['I',
#   'order',
#   'voodoo',
#   'pasta',
#   'first',
#   'time',
#   'I',
#   'realli',
#   'excel',
#   'pasta',
#   'sinc',
#   'go',
#   'gluten',
#   'free',
#   'sever',
#   'year',
#   'ago',
#   ''],
#  ['I', 'probabl', 'would', 'go', ''],
#  ['thi',
#   'realli',
#   'vega',
#   'fine',
#   'dine',
#   'use',
#   'right',
#   'menu',
#   'hand',
#   'ladi',
#   'price',
#   'list',
#   ''],
#  ['highli', 'recommend', ''],
#  ['give', 'tri', 'happi', ''],
#  ['If', 'want', 'sandwich', 'go', 'firehous', ''],
#  ['the', 'ambianc', 'much', 'better', ''],
#  ['It', 'equal', 'aw', ''],
#  ['the', 'food', 'good', 'typic', 'bar', 'food', ''],
#  ['the',
#   'ambianc',
#   'feel',
#   'like',
#   'buffet',
#   'set',
#   'douchey',
#   'indoor',
#   'garden',
#   'tea',
#   'biscuit',
#   ''],
#  ['We', 'ask', 'bill', 'leav', 'without', 'eat', 'bring', 'either', ''],
#  ['thi', 'place', 'qualiti', 'sushi', 'qualiti', 'restaur', ''],
#  ['after', 'one', 'bite', 'I', 'hook', ''],
#  ['Go', 'To', 'place', 'gyro', ''],
#  ['I', 'love', 'bacon', 'wrap', 'date', ''],
#  ['', 'they', 'never', 'brought', 'salad', 'ask', ''],
#  ['the', 'fri', 'hot', 'neither', 'burger', ''],
#  ['I', 'like', 'steiner', 'dark', 'feel', 'like', 'bar', ''],
#  ['the',
#   'tabl',
#   'outsid',
#   'also',
#   'dirti',
#   'lot',
#   'time',
#   'worker',
#   'alway',
#   'friendli',
#   'help',
#   'menu',
#   ''],
#  ['server', 'great', 'job', 'handl', 'larg', 'rowdi', 'tabl', ''],
#  ['thi', 'place', 'I', 'first', 'pho', 'amaz', ''],
#  ['poor',
#   'servic',
#   'waiter',
#   'made',
#   'feel',
#   'like',
#   'I',
#   'stupid',
#   'everi',
#   'time',
#   'came',
#   'tabl',
#   ''],
#  ['It', 'not', 'hard', 'make', 'decent', 'hamburg', ''],
#  ['and', 'bean', 'rice', 'mediocr', 'best', ''],
#  ['thi', 'first', 'vega', 'buffet', 'disappoint', ''],
#  ['hell', 'I', 'go', 'back'],
#  ['potato', 'great', 'biscuit', ''],
#  ['the', 'cashier', 'friendli', 'even', 'brought', 'food', ''],
#  ['the', 'food', 'came', 'good', 'pace', ''],
#  ['I',
#   'realli',
#   'sure',
#   'joey',
#   'vote',
#   'best',
#   'hot',
#   'dog',
#   'valley',
#   'reader',
#   'phoenix',
#   'magazin',
#   ''],
#  ['the',
#   'wife',
#   'hate',
#   'meal',
#   'coconut',
#   'shrimp',
#   'friend',
#   'realli',
#   'enjoy',
#   'meal',
#   'either',
#   ''],
#  ['alway', 'pleasur', 'deal', ''],
#  ['the', 'ambianc', 'incred', ''],
#  ['I', 'know', 'big', 'deal', 'place', 'I', 'back', 'ya', ''],
#  ['Do', 'favor', 'stay', 'away', 'dish', ''],
#  ['As', 'servic', 'I', 'fan', 'quick', 'serv', 'nice', 'folk', ''],
#  ['We',
#   'gotten',
#   'much',
#   'better',
#   'servic',
#   'pizza',
#   'place',
#   'next',
#   'door',
#   'servic',
#   'receiv',
#   'restaur',
#   ''],
#  ['their', 'menu', 'divers', 'reason', 'price', ''],
#  ['We', 'return', ''],
#  ['We', 'wait', 'forti', 'five', 'minut', 'vain', ''],
#  ['and', 'servic', 'super', 'friendli', ''],
#  ['present', 'food', 'aw', ''],
#  ['when', 'I', 'side', 'town', 'definit', 'spot', 'I', 'hit', ''],
#  ['At', 'least', '40min', 'pass', 'us', 'order', 'food', 'arriv', 'busi', ''],
#  ['thi', 'unbeliev', 'bargain', ''],
#  ['the',
#   'steak',
#   'amaz',
#   'rge',
#   'fillet',
#   'relleno',
#   'best',
#   'seafood',
#   'plate',
#   'ever',
#   ''],
#  ['I',
#   'love',
#   'mussel',
#   'cook',
#   'wine',
#   'reduct',
#   'duck',
#   'tender',
#   'potato',
#   'dish',
#   'delici',
#   ''],
#  ['On',
#   'ground',
#   'right',
#   'next',
#   'tabl',
#   'larg',
#   'smear',
#   'step',
#   'track',
#   'everywher',
#   'pile',
#   'green',
#   'bird',
#   'poop',
#   ''],
#  ['our',
#   'server',
#   'nice',
#   'even',
#   'though',
#   'look',
#   'littl',
#   'overwhelm',
#   'need',
#   'stay',
#   'profession',
#   'friendli',
#   'end',
#   ''],
#  ['I', 'got', 'enjoy', 'seafood', 'salad', 'fabul', 'vinegrett', ''],
#  ['all', 'I', 'assur', 'I', 'back', ''],
#  ['I', 'pretti', 'satifi', 'experi', ''],
#  ['As', 'sushi', 'lover', 'avoid', 'place', 'mean', ''],
#  ['although',
#   'I',
#   'much',
#   'like',
#   'look',
#   'sound',
#   'place',
#   'actual',
#   'experi',
#   'bit',
#   'disappoint',
#   ''],
#  ['they',
#   'horribl',
#   'attitud',
#   'toward',
#   'custom',
#   'talk',
#   'one',
#   'custom',
#   'enjoy',
#   'food',
#   ''],
#  ['thi', 'great', 'restaur', 'mandalay', 'bay', ''],
#  ['great',
#   'place',
#   'eat',
#   'remind',
#   'littl',
#   'mom',
#   'pop',
#   'shop',
#   'san',
#   'francisco',
#   'bay',
#   'area',
#   ''],
#  ['the',
#   'chipolt',
#   'ranch',
#   'dip',
#   'saus',
#   'tasteless',
#   'seem',
#   'thin',
#   'water',
#   'heat',
#   ''],
#  ['the', 'worst', 'experi', 'ever', ''],
#  ['It', 'fun', 'experi', ''],
#  ['I', 'back', ''],
#  ['the', 'chicken', 'dish', 'OK', 'beef', 'like', 'shoe', 'leather', ''],
#  ['the', 'fri', 'great', ''],
#  ['not',
#   'singl',
#   'employe',
#   'came',
#   'see',
#   'OK',
#   'even',
#   'need',
#   'water',
#   'refil',
#   'final',
#   'serv',
#   'us',
#   'food',
#   ''],
#  ['ampl', 'portion', 'good', 'price', ''],
#  ['I',
#   'far',
#   'sushi',
#   'connoisseur',
#   'I',
#   'definit',
#   'tell',
#   'differ',
#   'good',
#   'food',
#   'bad',
#   'food',
#   'certainli',
#   'bad',
#   'food',
#   ''],
#  ['great', 'place', 'relax', 'awesom', 'burger', 'beer', ''],
#  ['overal',
#   'I',
#   'think',
#   'I',
#   'would',
#   'take',
#   'parent',
#   'place',
#   'made',
#   'similar',
#   'complaint',
#   'I',
#   'silent',
#   'felt',
#   ''],
#  ['food', 'realli', 'bore', ''],
#  ['An', 'extens', 'menu', 'provid', 'lot', 'option', 'breakfast', ''],
#  ['We',
#   'recent',
#   'wit',
#   'poor',
#   'qualiti',
#   'manag',
#   'toward',
#   'guest',
#   'well',
#   ''],
#  ['drive',
#   'thru',
#   'mean',
#   'want',
#   'wait',
#   'around',
#   'half',
#   'hour',
#   'food',
#   'somehow',
#   'end',
#   'go',
#   'make',
#   'us',
#   'wait',
#   'wait',
#   ''],
#  ['nicest', 'chines', 'restaur', 'I', ''],
#  ['their', 'rotat', 'beer', 'tap', 'also', 'highlight', 'place', ''],
#  ['the', 'restaur', 'atmospher', 'exquisit', ''],
#  ['',
#   'the',
#   'owner',
#   'realli',
#   'realli',
#   'need',
#   'quit',
#   'soooooo',
#   'cheap',
#   'let',
#   'wrap',
#   'freak',
#   'sandwich',
#   'two',
#   'paper',
#   'one',
#   ''],
#  ['I', 'love', 'fact', 'everyth', 'menu', 'worth', ''],
#  ['I', 'take', 'littl', 'bad', 'servic', 'food', 'suck', ''],
#  ['My',
#   'fiancé',
#   'I',
#   'came',
#   'middl',
#   'day',
#   'greet',
#   'seat',
#   'right',
#   'away',
#   ''],
#  ['the',
#   'staff',
#   'super',
#   'nice',
#   'quick',
#   'even',
#   'crazi',
#   'crowd',
#   'downtown',
#   'juri',
#   'lawyer',
#   'court',
#   'staff',
#   ''],
#  ['the', 'macaron', 'insan', 'good', ''],
#  ['No',
#   'allergi',
#   'warn',
#   'menu',
#   'waitress',
#   'absolut',
#   'clue',
#   'meal',
#   'contain',
#   'peanut',
#   ''],
#  ['I', 'realli', 'recommend', 'place', 'go', 'wrong', 'donut', 'place', ''],
#  ['the', 'servic', 'extrem', 'slow', ''],
#  ['It', 'attach', 'ga', 'station', 'rare', 'good', 'sign', ''],
#  ['the',
#   'servic',
#   'littl',
#   'slow',
#   'consid',
#   'serv',
#   '3',
#   'peopl',
#   'server',
#   'food',
#   'come',
#   'slow',
#   'pace',
#   ''],
#  ['the',
#   'menu',
#   'alway',
#   'chang',
#   'food',
#   'qualiti',
#   'go',
#   'servic',
#   'extrem',
#   'slow',
#   ''],
#  ['cute', 'quaint', 'simpl', 'honest', ''],
#  ['If',
#   'want',
#   'wait',
#   'mediocr',
#   'food',
#   'downright',
#   'terribl',
#   'servic',
#   'place',
#   ''],
#  ['never', 'anyth', 'complain', ''],
#  ['the',
#   'atmospher',
#   'great',
#   'love',
#   'duo',
#   'violinist',
#   'play',
#   'song',
#   'request',
#   ''],
#  ['5', 'star', 'brick', 'oven', 'bread', 'app', ''],
#  ['the', 'manag', 'worst', ''],
#  ['the', 'black', 'eye', 'pea', 'sweet', 'potato', 'unreal', ''],
#  ['the', 'food', 'suck', 'expect', 'suck', 'could', 'imagin', ''],
#  ['the',
#   'guy',
#   'steak',
#   'steak',
#   'love',
#   'son',
#   'steak',
#   'best',
#   'worst',
#   'place',
#   'said',
#   'best',
#   'steak',
#   'ever',
#   'eaten',
#   ''],
#  ['the', 'price', 'reason', 'servic', 'great', ''],
#  ['We',
#   'made',
#   'drive',
#   'way',
#   'north',
#   'scottsdal',
#   'I',
#   'one',
#   'bit',
#   'disappoint',
#   ''],
#  ['and', 'red', 'curri', 'much', 'bamboo', 'shoot', 'tasti', ''],
#  ['My',
#   'husband',
#   'said',
#   'rude',
#   'even',
#   'apolog',
#   'bad',
#   'food',
#   'anyth',
#   ''],
#  ['I', 'never', 'insult', 'felt', 'disrespect', ''],
#  ['I', 'eat', ''],
#  ['I', 'mac', 'salad', 'pretti', 'bland', 'I', 'get', ''],
#  ['I',
#   'live',
#   'neighborhood',
#   'I',
#   'disappoint',
#   'I',
#   'back',
#   'conveni',
#   'locat',
#   ''],
#  ['thi', 'one', 'simpli', 'disappoint', ''],
#  ['servic', 'fine', 'waitress', 'friendli', ''],
#  ['It', 'probabl', 'dirt', ''],
#  ['the', 'warm', 'beer', 'help', ''],
#  ['wow', 'spici', 'delici', ''],
#  ['serious', 'flavor', 'delight', 'folk', ''],
#  ['gave', 'tri', 'eat', 'crust', 'teeth', 'still', 'sore', ''],
#  ['waaaaaayyyyyyyyyi', 'rate', 'I', 'say', ''],
#  ['tast', 'like', 'dirt', ''],
#  ['after', 'disappoint', 'dinner', 'went', 'elsewher', 'dessert', ''],
#  ['I', 'paid', 'bill', 'tip', 'I', 'felt', 'server', 'terribl', 'job', ''],
#  ['after', '20', 'minut', 'wait', 'I', 'got', 'tabl', ''],
#  ['definit',
#   'worth',
#   'ventur',
#   'strip',
#   'pork',
#   'belli',
#   'return',
#   'next',
#   'time',
#   'I',
#   'vega',
#   ''],
#  ['I',
#   'proven',
#   'dead',
#   'wrong',
#   'sushi',
#   'bar',
#   'qualiti',
#   'great',
#   'servic',
#   'fast',
#   'food',
#   'impecc',
#   ''],
#  ['I', 'account', 'know', 'I', 'get', 'screw', ''],
#  ['the', 'chain', 'I', 'fan', 'beat', 'place', 'easili', ''],
#  ['My', 'sashimi', 'poor', 'qualiti', 'soggi', 'tasteless', ''],
#  ['probabl', 'never', 'come', 'back', 'recommend', ''],
#  ['how',
#   'call',
#   'steakhous',
#   'properli',
#   'cook',
#   'steak',
#   'I',
#   'understand',
#   ''],
#  ['', 'food', 'rich', 'order', 'accordingli', ''],
#  ['I', 'eat', ''],
#  ['the', 'thing', 'I', 'crazi', 'guacamol', 'I', 'like', 'puré', ''],
#  ['level', '5', 'spici', 'perfect', 'spice', 'whelm', 'soup', ''],
#  ['I', 'could', 'eat', 'bruschetta', 'day', 'devin', ''],
#  ['what',
#   'should',
#   'hilari',
#   'yummi',
#   'christma',
#   'eve',
#   'dinner',
#   'rememb',
#   'biggest',
#   'fail',
#   'entir',
#   'trip',
#   'us',
#   ''],
#  ['pretti', 'awesom', 'place', ''],
#  ['weird', 'vibe', 'owner', ''],
#  ['food', 'good', 'servic', 'good', 'price', 'good', ''],
#  ['I', 'come', 'back', 'everi', 'time', 'I', 'vega', ''],
#  ['unfortun', 'set', 'us', 'disapppoint', 'entre', ''],
#  ['thoroughli', 'disappoint', ''],
#  ['thu', 'far', 'visit', 'twice', 'food', 'absolut', 'delici', 'time', ''],
#  ['thi', 'place', 'honestli', 'blown', ''],
#  ['I', 'love', 'go', 'back', ''],
#  ['the', 'pancak', 'also', 'realli', 'good', 'pretti', 'larg', ''],
#  ['thi',
#   'realli',
#   'fantast',
#   'thai',
#   'restaur',
#   'definit',
#   'worth',
#   'visit',
#   ''],
#  ['I', 'probabl', 'back', 'honest', ''],
#  ['veri', 'fun', 'chef', ''],
#  ['the',
#   'feel',
#   'dine',
#   'room',
#   'colleg',
#   'cook',
#   'cours',
#   'high',
#   'class',
#   'dine',
#   'servic',
#   'slow',
#   'best',
#   ''],
#  ['I', 'want', 'leav', ''],
#  ['I', 'promis', 'disappoint', ''],
#  ['they',
#   'custom',
#   'order',
#   'way',
#   'like',
#   'usual',
#   'eggplant',
#   'green',
#   'bean',
#   'stir',
#   'fri',
#   'love',
#   ''],
#  ['We',
#   'start',
#   'tuna',
#   'sashimi',
#   'brownish',
#   'color',
#   'obvious',
#   'fresh',
#   ''],
#  ['I',
#   'ate',
#   'twice',
#   'last',
#   'visit',
#   'especi',
#   'enjoy',
#   'salmon',
#   'salad',
#   ''],
#  ['order',
#   'doubl',
#   'cheeseburg',
#   'got',
#   'singl',
#   'patti',
#   'fall',
#   'apart',
#   'pictur',
#   'upload',
#   'yeah',
#   'still',
#   'suck',
#   ''],
#  ['the', 'nacho', 'must', 'have', ''],
#  ['I', 'wait', 'go', 'back', ''],
#  ['back',
#   'good',
#   'bbq',
#   'lighter',
#   'fare',
#   'reason',
#   'price',
#   'tell',
#   'public',
#   'back',
#   'old',
#   'way',
#   ''],
#  ['great', 'food', ''],
#  ['I', 'know', 'kind', 'best', 'ice', 'tea', ''],
#  ['highli', 'unprofession', 'rude', 'loyal', 'patron', ''],
#  ['I', 'mean', 'realli', 'get', 'famou', 'fish', 'chip', 'terribl', ''],
#  ['best', 'fish', 'I', 'ever', 'life', ''],
#  ['they', 'know', 'make', ''],
#  ['will', 'back', ''],
#  ['ani', 'grandmoth', 'make', 'roast', 'chicken', 'better', 'one', ''],
#  ['same', 'even', 'I', 'drastic', 'sick', ''],
#  ['I', 'wait', 'wait', ''],
#  ['I', 'took', 'back', 'money', 'got', 'outta', ''],
#  ['will',
#   'never',
#   'ever',
#   'GO',
#   'back',
#   'and',
#   'have',
#   'told',
#   'mani',
#   'peopl',
#   'what',
#   'had',
#   'happen',
#   ''],
#  ['It', 'either', 'cold', 'enough', 'flavor', 'bad', ''],
#  ['con', 'spotti', 'servic', ''],
#  ['I', 'love', 'place', ''],
#  ['great', 'pork', 'sandwich', ''],
#  ['classi',
#   'warm',
#   'atmospher',
#   'fun',
#   'fresh',
#   'appet',
#   'succul',
#   'steak',
#   'basebal',
#   'steak',
#   ''],
#  ['I', 'would', 'recommend', 'place', ''],
#  ['thi', 'good', 'joint', ''],
#  ['It', 'lack', 'flavor', 'seem', 'undercook', 'dri', ''],
#  ['We',
#   'one',
#   'make',
#   'scene',
#   'restaur',
#   'I',
#   'get',
#   'definit',
#   'lost',
#   'love',
#   'one',
#   ''],
#  ['also', 'I', 'feel', 'like', 'chip', 'bought', 'made', 'hous', ''],
#  ['I', 'return', ''],
#  ['My', 'fella', 'got', 'huevo', 'ranchero', 'look', 'appeal', ''],
#  ['thi', 'place', 'nice', 'surpris', ''],
#  ['veri', 'bad', 'experi', ''],
#  ['I', 'would', 'recommend', 'place', ''],
#  ['avoid', 'thi', 'establish', ''],
#  ['the', 'real', 'disappoint', 'waiter', ''],
#  ['servic', 'good', 'compani', 'better', ''],
#  ['So',
#   'good',
#   'I',
#   'go',
#   'review',
#   'place',
#   'twice',
#   'herea',
#   'tribut',
#   'place',
#   'tribut',
#   'event',
#   'held',
#   'last',
#   'night',
#   ''],
#  ['I', 'love', 'pho', 'spring', 'roll', 'oh', 'yummi', 'tri', ''],
#  ['By', 'time', 'side', 'restaur', 'almost', 'empti', 'excus', ''],
#  ['needless', 'say', 'never', 'back', ''],
#  ['unfortun',
#   'must',
#   'hit',
#   'bakeri',
#   'leftov',
#   'day',
#   'everyth',
#   'order',
#   'stale',
#   ''],
#  ['those', 'burger', 'amaz', ''],
#  ['the', 'redeem', 'qualiti', 'restaur', 'inexpens', ''],
#  ['I', 'opportun', 'today', 'sampl', 'amaz', 'pizza', ''],
#  ['We',
#   'also',
#   'order',
#   'spinach',
#   'avocado',
#   'salad',
#   'ingredi',
#   'sad',
#   'dress',
#   'liter',
#   'zero',
#   'tast',
#   ''],
#  ['the', 'patio', 'seat', 'comfort', ''],
#  ['My',
#   'boyfriend',
#   'tri',
#   'mediterranean',
#   'chicken',
#   'salad',
#   'fell',
#   'love',
#   ''],
#  ['some',
#   'may',
#   'say',
#   'buffet',
#   'pricey',
#   'I',
#   'think',
#   'get',
#   'pay',
#   'place',
#   'get',
#   'quit',
#   'lot',
#   ''],
#  ['In', 'fact', 'I', 'go', 'round', '4', 'star', 'awesom', ''],
#  ['the', 'cashew', 'cream', 'sauc', 'bland', 'veget', 'undercook', ''],
#  ['overal', 'I', 'like', 'food', 'servic', ''],
#  ['We', 'never', 'go', ''],
#  ['I',
#   'believ',
#   'place',
#   'great',
#   'stop',
#   'huge',
#   'belli',
#   'hanker',
#   'sushi',
#   ''],
#  ['horribl', 'wast', 'time', 'money', ''],
#  ['I',
#   'sure',
#   'long',
#   'stood',
#   'long',
#   'enough',
#   'begin',
#   'feel',
#   'awkwardli',
#   'place',
#   ''],
#  ['our', 'server', 'super', 'nice', 'check', 'us', 'mani', 'time', ''],
#  ['It', 'absolut', 'amaz', ''],
#  ['definit', 'worth', '3', 'I', 'paid', ''],
#  ['I', 'guess', 'mayb', 'went', 'night', 'disgrac', ''],
#  ['serious', 'killer', 'hot', 'chai', 'latt', ''],
#  ['I',
#   'live',
#   'sinc',
#   '1979',
#   'first',
#   'last',
#   'time',
#   'I',
#   'step',
#   'foot',
#   'place',
#   ''],
#  ['I', 'sever', 'time', 'past', 'experi', 'alway', 'great', ''],
#  ['My',
#   'brother',
#   'law',
#   'work',
#   'mall',
#   'ate',
#   'day',
#   'guess',
#   'sick',
#   'night',
#   ''],
#  ['kid',
#   'pizza',
#   'alway',
#   'hit',
#   'lot',
#   'great',
#   'side',
#   'dish',
#   'option',
#   'kiddo',
#   ''],
#  ['one', 'place', 'phoenix', 'I', 'would', 'defin', 'go', 'back', ''],
#  ['To',
#   'disbelief',
#   'dish',
#   'qualifi',
#   'worst',
#   'version',
#   'food',
#   'I',
#   'ever',
#   'tast',
#   ''],
#  ['the', 'jamaican', 'mojito', 'delici', ''],
#  ['the', 'select', 'menu', 'great', 'price', ''],
#  ['It',
#   'close',
#   'hous',
#   'low',
#   'key',
#   'non',
#   'fanci',
#   'afford',
#   'price',
#   'good',
#   'food',
#   ''],
#  ['our', 'waiter', 'attent', 'friendli', 'inform', ''],
#  ['disappoint', 'experi', ''],
#  ['the',
#   'chicken',
#   'I',
#   'got',
#   'definit',
#   'reheat',
#   'ok',
#   'wedg',
#   'cold',
#   'soggi',
#   ''],
#  ['I', 'love', 'decor', 'chines', 'calligraphi', 'wall', 'paper', ''],
#  ['last',
#   'night',
#   'second',
#   'time',
#   'dine',
#   'I',
#   'happi',
#   'I',
#   'decid',
#   'go',
#   'back',
#   ''],
#  ['great', 'food', 'awesom', 'servic', ''],
#  ['veri', 'good', 'food', 'great', 'atmospher', '1'],
#  ['It', 'good', ''],
#  ['they', 'golden', 'crispi', 'delici', ''],
#  ['A', 'fli', 'appl', 'juic', 'A', 'fli', ''],
#  ['He',
#   'also',
#   'came',
#   'back',
#   'check',
#   'us',
#   'regularli',
#   'excel',
#   'servic',
#   ''],
#  ['I', 'definit', 'soon', ''],
#  ['cant', 'say', 'enough', 'good', 'thing', 'place', ''],
#  ['the', 'burger', 'good', 'beef', 'cook', 'right', ''],
#  ['I', 'found', 'place', 'accid', 'I', 'could', 'happier', ''],
#  ['unfortun', 'good', ''],
#  ['I', 'recent', 'tri', 'caballero', 'I', 'back', 'everi', 'week', 'sinc', ''],
#  ['I',
#   'heard',
#   'good',
#   'thing',
#   'place',
#   'exceed',
#   'everi',
#   'hope',
#   'I',
#   'could',
#   'dream',
#   ''],
#  ['delici',
#   'nyc',
#   'bagel',
#   'good',
#   'select',
#   'cream',
#   'chees',
#   'real',
#   'lox',
#   'caper',
#   'even',
#   ''],
#  ['thi',
#   'hole',
#   'wall',
#   'great',
#   'mexican',
#   'street',
#   'taco',
#   'friendli',
#   'staff',
#   ''],
#  ['I', 'found', 'six', 'inch', 'long', 'piec', 'wire', 'salsa', ''],
#  ['thi',
#   'wonder',
#   'experi',
#   'made',
#   'place',
#   'must',
#   'stop',
#   'whenev',
#   'town',
#   ''],
#  ['how', 'awesom', ''],
#  ['food', 'tasti', 'say', 'real', 'tradit', 'hunan', 'style', ''],
#  ['rude', 'inconsider', 'manag', ''],
#  ['thi', 'place', 'amaz', ''],
#  ['first', 'time', 'go', 'I', 'think', 'I', 'quickli', 'becom', 'regular', ''],
#  ['awesom', 'servic', 'food', ''],
#  ['I',
#   'continu',
#   'come',
#   'ladi',
#   'night',
#   'andddd',
#   'date',
#   'night',
#   'highli',
#   'recommend',
#   'place',
#   'anyon',
#   'area',
#   ''],
#  ['omg',
#   'I',
#   'felt',
#   'like',
#   'I',
#   'never',
#   'eaten',
#   'thai',
#   'food',
#   'dish',
#   ''],
#  ['their', 'monster', 'chicken', 'fri', 'steak', 'egg', 'time', 'favorit', ''],
#  ['He',
#   'extrem',
#   'rude',
#   'realli',
#   'mani',
#   'restaur',
#   'I',
#   'would',
#   'love',
#   'dine',
#   'weekend',
#   'vega',
#   ''],
#  ['the', 'cocktail', 'handmad', 'delici', ''],
#  ['the', 'one', 'note', 'ventil', 'could', 'use', 'upgrad', ''],
#  ['food', 'averag', 'best', ''],
#  ['I', 'return', ''],
#  ['bad',
#   'caus',
#   'I',
#   'know',
#   'famili',
#   'own',
#   'I',
#   'realli',
#   'want',
#   'like',
#   'place',
#   ''],
#  ['Oh', 'thing', 'beauti', 'restaur', ''],
#  ['food', 'way', 'overpr', 'portion', 'fuck', 'small', ''],
#  ['she',
#   'quit',
#   'disappoint',
#   'although',
#   'blame',
#   'need',
#   'place',
#   'door',
#   ''],
#  ['We', 'glad', 'found', 'place', ''],
#  ['thi', 'place', 'overpr', 'consist', 'boba', 'realli', 'overpr', ''],
#  ['I', 'disgust', 'I', 'pretti', 'sure', 'human', 'hair', ''],
#  ['differ',
#   'cut',
#   'piec',
#   'day',
#   'still',
#   'wonder',
#   'tender',
#   'well',
#   'well',
#   'flavor',
#   ''],
#  ['the', 'shrimp', 'tender', 'moist', ''],
#  ['wors',
#   'humili',
#   'worker',
#   'right',
#   'front',
#   'bunch',
#   'horribl',
#   'name',
#   'call',
#   ''],
#  ['the',
#   'staff',
#   'friendli',
#   'wait',
#   'time',
#   'serv',
#   'horribl',
#   'one',
#   'even',
#   'say',
#   'hi',
#   'first',
#   '10',
#   'minut',
#   ''],
#  ['interest', 'decor', ''],
#  ['but', 'servic', 'beyond', 'bad', ''],
#  ['soggi', 'good', ''],
#  ['onc', 'food', 'arriv', 'meh', ''],
#  ['their', 'chow', 'mein', 'good', ''],
#  ['I',
#   'love',
#   'owner',
#   'chef',
#   'one',
#   'authent',
#   'japanes',
#   'cool',
#   'dude',
#   ''],
#  ['the',
#   'burger',
#   'I',
#   'got',
#   'gold',
#   'standard',
#   '17',
#   'burger',
#   'kind',
#   'disappoint',
#   ''],
#  ['I',
#   'watch',
#   'price',
#   'inflat',
#   'portion',
#   'get',
#   'smaller',
#   'manag',
#   'attitud',
#   'grow',
#   'rapidli',
#   ''],
#  ['We',
#   'order',
#   'old',
#   'classic',
#   'new',
#   'dish',
#   'go',
#   'time',
#   'sore',
#   'disappoint',
#   'everyth',
#   ''],
#  ['awesom', 'select', 'beer', ''],
#  ['you', 'get', 'incred', 'fresh', 'fish', 'prepar', 'care', ''],
#  ['I', 'realli', 'impress', 'strip', 'steak', ''],
#  ['there', 'noth', 'privileg', 'work', 'eat', ''],
#  ['one',
#   'nice',
#   'thing',
#   'ad',
#   'gratuiti',
#   'bill',
#   'sinc',
#   'parti',
#   'larger',
#   '6',
#   '8',
#   'expect',
#   'tip',
#   ''],
#  ['the',
#   'vanilla',
#   'ice',
#   'cream',
#   'creami',
#   'smooth',
#   'profiterol',
#   'choux',
#   'pastri',
#   'fresh',
#   'enough',
#   ''],
#  ['the',
#   'chicken',
#   'wing',
#   'contain',
#   'driest',
#   'chicken',
#   'meat',
#   'I',
#   'ever',
#   'eaten',
#   ''],
#  ['appetit', 'instantli', 'gone', ''],
#  ['I', 'say', 'dessert', 'yummi', ''],
#  ['hot',
#   'dish',
#   'hot',
#   'cold',
#   'dish',
#   'close',
#   'room',
#   'temp',
#   'I',
#   'watch',
#   'staff',
#   'prepar',
#   'food',
#   'bare',
#   'hand',
#   'glove',
#   'everyth',
#   'deep',
#   'fri',
#   'oil',
#   ''],
#  ['for', 'self', 'proclaim', 'coffe', 'cafe', 'I', 'wildli', 'disappoint', ''],
#  ['food', 'great', 'serivc', ''],
#  ['I', 'seat', 'immedi', ''],
#  ['I', 'know', 'like', 'restaur', 'someth', ''],
#  ['As', 'servic', 'I', 'thought', 'good', ''],
#  ['overal', 'I', 'disappoint', 'qualiti', 'food', 'bouchon', ''],
#  ['have', 'go', 'sinc', '2007', 'everi', 'meal', 'awesom', ''],
#  ['We', 'enjoy', 'pizza', 'brunch', ''],
#  ['Do', 'wast', 'money', ''],
#  ['great', 'time', 'famili', 'dinner', 'sunday', 'night', ''],
#  ['So', 'went', 'tigerlilli', 'fantast', 'afternoon', ''],
#  ['I',
#   'never',
#   'go',
#   'back',
#   'place',
#   'never',
#   'ever',
#   'recommend',
#   'place',
#   'anyon',
#   ''],
#  ['def', 'come', 'back', 'bowl', 'next', 'time'],
#  ['crust', 'good', ''],
#  ['don', 'bother', 'come', ''],
#  ['food', 'averag', ''],
#  ['after', 'two', 'I', 'felt', 'disgust', ''],
#  ['come',
#   'like',
#   'experienc',
#   'underwhelm',
#   'relationship',
#   'parti',
#   'wait',
#   'person',
#   'ask',
#   'break',
#   ''],
#  ['veri', 'good', 'lunch', 'spot', ''],
#  ['overal', 'I', 'like', 'place', 'lot', ''],
#  ['their', 'frozen', 'margarita', 'way', 'sugari', 'tast', ''],
#  ['terribl', 'servic', ''],
#  ['waiter', 'jerk', ''],
#  ['the', 'last', '3', 'time', 'I', 'lunch', 'bad', ''],
#  ['My', 'wife', 'lobster', 'bisqu', 'soup', 'lukewarm', ''],
#  ['It',
#   'like',
#   'realli',
#   'sexi',
#   'parti',
#   'mouth',
#   'outrag',
#   'flirt',
#   'hottest',
#   'person',
#   'parti',
#   ''],
#  ['there', 'noth', 'authent', 'place', ''],
#  ['I', 'strawberri', 'tea', 'good', ''],
#  ['gener', 'portion', 'great', 'tast', ''],
#  ['pretti', 'good', 'beer', 'select', ''],
#  ['these', 'good', 'order', 'twice', ''],
#  ['now', 'dish', 'quit', 'flavour', ''],
#  ['I', 'tri', 'cape', 'cod', 'ravoli', 'chicken', 'cranberri', 'mmmm', ''],
#  ['the', 'bu', 'boy', 'hand', 'rude', ''],
#  ['I', 'miss', 'wish', 'one', 'philadelphia', ''],
#  ['thi', 'place', 'deserv', 'one', 'star', '90', 'food', ''],
#  ['stop', 'place', 'madison', 'ironman', 'friendli', 'kind', 'staff', ''],
#  ['thi',
#   'place',
#   'hand',
#   'one',
#   'best',
#   'place',
#   'eat',
#   'phoenix',
#   'metro',
#   'area',
#   ''],
#  ['40', 'buck', 'head', 'realli', 'expect', 'better', 'food', ''],
#  ['A',
#   'ladi',
#   'tabl',
#   'next',
#   'us',
#   'found',
#   'live',
#   'green',
#   'caterpillar',
#   'In',
#   'salad',
#   ''],
#  ['what', 'mistak', ''],
#  ['It', 'kept', 'get', 'wors', 'wors', 'I', 'offici', 'done', ''],
#  ['delici', 'I', 'absolut', 'back', ''],
#  ['I',
#   'place',
#   'eat',
#   'circumst',
#   'would',
#   'I',
#   'ever',
#   'return',
#   'top',
#   'list',
#   ''],
#  ['the', 'waitress', 'manag', 'friendli', ''],
#  ['veri', 'poor', 'servic', ''],
#  ['', 'It', 'busi', 'either', 'also', 'build', 'freez', 'cold', ''],
#  ['the',
#   'server',
#   'went',
#   'back',
#   'forth',
#   'sever',
#   'time',
#   'even',
#   'much',
#   'are',
#   'help',
#   ''],
#  ['there', 'hardli', 'meat', ''],
#  ['A', 'good', 'time', ''],
#  ['price',
#   'reason',
#   'flavor',
#   'spot',
#   'sauc',
#   'home',
#   'made',
#   'slaw',
#   'drench',
#   'mayo',
#   ''],
#  ['also',
#   'serv',
#   'hot',
#   'bread',
#   'butter',
#   'home',
#   'made',
#   'potato',
#   'chip',
#   'bacon',
#   'bit',
#   'top',
#   'origin',
#   'good',
#   ''],
#  ['perfect',
#   'someon',
#   'like',
#   'beer',
#   'ice',
#   'cold',
#   'case',
#   'even',
#   'colder',
#   ''],
#  ['anyway', 'the', 'food', 'definit', 'fill', 'price', 'pay', 'expect', ''],
#  ['third', 'chees', 'friend', 'burger', 'cold', ''],
#  ['your', 'staff', 'spend', 'time', 'talk', ''],
#  ['I',
#   'much',
#   'pasta',
#   'I',
#   'love',
#   'homemad',
#   'hand',
#   'made',
#   'pasta',
#   'thin',
#   'pizza',
#   ''],
#  ['the',
#   'salad',
#   'right',
#   'amount',
#   'sauc',
#   'power',
#   'scallop',
#   'perfectli',
#   'cook',
#   ''],
#  ['total',
#   'letdown',
#   'I',
#   'would',
#   'much',
#   'rather',
#   'go',
#   'camelback',
#   'flower',
#   'shop',
#   'cartel',
#   'coffe',
#   ''],
#  ['My', 'salad', 'bland', 'vinegrett', 'babi', 'green', 'heart', 'palm', ''],
#  ['went', 'happi', 'hour', 'great', 'list', 'wine', ''],
#  ['I',
#   'alway',
#   'order',
#   'vegetarian',
#   'menu',
#   'dinner',
#   'wide',
#   'array',
#   'option',
#   'choos',
#   ''],
#  ['the', 'greek', 'dress', 'creami', 'flavor', ''],
#  ['the', 'food', 'amaz', ''],
#  ['never', 'go', 'back', ''],
#  ['We', 'love', 'place', ''],
#  ['I', 'came', 'back', 'today', 'sinc', 'reloc', 'still', 'impress', ''],
#  ['I', 'like', 'patio', 'servic', 'outstand', ''],
#  ['but', 'came', 'back', 'cold', ''],
#  ['both', 'egg', 'roll', 'fantast', ''],
#  ['I', 'recommend', 'unless', 'car', 'break', 'front', 'starv', ''],
#  ['I',
#   'high',
#   'hope',
#   'place',
#   'sinc',
#   'burger',
#   'cook',
#   'charcoal',
#   'grill',
#   'unfortun',
#   'tast',
#   'fell',
#   'flat',
#   'way',
#   'flat',
#   ''],
#  ['I', 'assur', 'disappoint', ''],
#  ['the', 'menu', 'much', 'good', 'stuff', 'could', 'decid', ''],
#  ['It', 'worth', 'drive', 'tucson', ''],
#  ['',
#   'both',
#   'hot',
#   'sour',
#   'egg',
#   'flower',
#   'soup',
#   'absolut',
#   '5',
#   'star',
#   ''],
#  ['In', 'summer', 'dine', 'charm', 'outdoor', 'patio', 'delight', ''],
#  ['veri', 'conveni', 'sinc', 'stay', 'mgm', ''],
#  ['thi', 'place', 'way', 'overpr', 'mediocr', 'food', ''],
#  ['both', 'great', ''],
#  ['worst', 'sushi', 'ever', 'eat', 'besid', 'costco', ''],
#  ['On', 'side', 'cafe', 'serv', 'realli', 'good', 'food', ''],
#  ['the', 'dine', 'space', 'tini', 'elegantli', 'decor', 'comfort', ''],
#  ['all', 'I', 'say', 'food', 'amaz', ''],
#  ['best', 'tater', 'tot', 'southwest', ''],
#  ['the',
#   'server',
#   'pleasant',
#   'deal',
#   'alway',
#   'honor',
#   'pizza',
#   'hut',
#   'coupon',
#   ''],
#  ['extrem', 'tasti', ''],
#  ['I', 'think', 'I', 'run', 'back', 'carli', 'anytim', 'soon', 'food', ''],
#  ['worst', 'servic', 'boot', 'least', 'worri', ''],
#  ['An', 'absolut', 'must', 'visit', ''],
#  ['the', 'burritto', 'blah', ''],
#  ['the', 'chip', 'came', 'drip', 'greas', 'mostli', 'edibl', ''],
#  ['', 'realli', 'realli', 'good', 'rice', 'time', ''],
#  ['the',
#   'food',
#   'delici',
#   'bartend',
#   'attent',
#   'person',
#   'and',
#   'got',
#   'great',
#   'deal',
#   ''],
#  ['the', 'veggitarian', 'platter', 'world', ''],
#  ['thi', 'place', 'pretti', 'good', 'nice', 'littl', 'vibe', 'restaur', ''],
#  ['It',
#   'huge',
#   'awkward',
#   '1',
#   '5lb',
#   'piec',
#   'cow',
#   '3',
#   '4th',
#   'gristl',
#   'fat',
#   ''],
#  ['best', 'buffet', 'town', 'price', 'cannot', 'beat', '']]
# CPU times: user 406 ms, sys: 449 ms, total: 854 ms
# Wall time: 1.06 s

# %% [markdown]
# **6) ** Create 'Train' and 'Test' data sets (i.e. 70% of the underlying data set will constitute the training set and 30% of the underlying data set will constitute the test set)

# %% [markdown]
# **7)** Train a Naive Bayes model on the Train data set and test it against the test data set

# %% [markdown]
# **8) **Construct a confusion matirx to gauge the performance of the model
